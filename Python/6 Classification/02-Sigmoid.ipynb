# %%
from IPython.core.display import HTML
with open ("../style.css", "r") as file:
    css = file.read()
HTML(css)
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
# <link href="http://fonts.googleapis.com/css?family=Sacramento" rel="stylesheet" type="text/css">
#
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# .container { width: 100% }
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Philosopher', sans-serif;
#     font-weight: 400;
#     font-size: 2.2em;
#     line-height: 100%;
#     color: rgb(0, 80, 120);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Philosopher', serif;
#     font-weight: 400;
#     font-size: 1.9em;
#     line-height: 100%;
#     color: rgb(200,100,0);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Philosopher', serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(94,127,192);
# }
#
# .text_cell_render h4 {
#     font-family: 'Philosopher', serif;
# }
#
# .text_cell_render h5 {
#     font-family: 'Alegreya Sans', sans-serif;
#     font-weight: 300;
#     font-size: 16pt;
#     color: grey;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .text_cell_render em {
#     font-family: 'Philosopher', sans-serif;
#     color:        blue;
#     background-color: rgb(255,220,180);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   100;
# }
#
# .text_cell_render b {
#     color:            rgb(255,195,195);
#     background-color: rgb(0,0,0);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   650;
# }
#
# .text_cell_render u {
#     color:            blue;
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   650;
# }
#
# .text_cell_render tt {
#     font-size:    120%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   150;
# }
#
# .Codemirror {
#     font-family: "PT Mono";
#     font-size: 100%;
# }
#
# #fancy {
#     font-family:      Georgia;
#     position:         relative;
#     float:            left;
#     border:           2px solid red;
#     width:            600px;
#     padding-left:     20px;
#     padding-right:    20px;
#     padding-top:      10px;
#     font-family:      'Sacramento', cursive;
#     font-size:        26px;
#     background-color: #F4EBF3;
#     border-radius:    15px;
# }
#
# </Style>

# %% [markdown]
# # The Sigmoid Function

# %%
import matplotlib.pyplot as plt 
import seaborn           as sns
import numpy             as np
from math import *

# %% [markdown]
# The sigmoid function $S:\mathbb{R} \rightarrow [0,1]$ is defined as:
# $$ S(t) = \frac{1}{1 + \exp(-t)}. $$

# %%
def sigmoid(t):
    "Returns the sigmoid function S(t)"
    return 1 / (1 + np.exp(-t))

# %% [markdown]
# Let us plot this function.

# %%
n = 1000
X = np.linspace(-8.0, 8.0, num=n)
Y = sigmoid(X)
plt.figure(figsize=(15, 10))
sns.set(style='whitegrid')
plt.margins(0.02)
plt.plot(X, Y)
plt.axvline(x=0.0, c='k')
plt.axhline(y=0.0, c='k')
plt.xlabel("x")
plt.ylabel("y")
plt.xticks(np.arange(-8.0, 8.1, step=0.5))
plt.yticks(np.arange(0.0, 1.01, step=0.05))
plt.title("The Sigmoid Function S(x) = 1/(1+exp(-x)).");

# %% [markdown]
# It can be shown that the derivative of the sigmoid function satisfies the equation
# $$ \frac{\mathrm{d}S}{\mathrm{d}x}(t) = S(t) \cdot \bigl(1 - S(t)\bigr) $$

# %%
def sigmoidPrime(t):
    """
    compute the derivative of the sigmoid function
    """
    return sigmoid(t) * (1 - sigmoid(t))

# %% [markdown]
# The Gauss function with standard deviation $\sigma$ is defined as
# $$ t \mapsto \frac{1}{\sqrt{2\cdot\pi}\cdot\sigma} \cdot \exp\left(-\frac{t^2}{2\cdot \sigma^2}\right)$$

# %%
def gauss(t):
    "Return the Gauss function with standard deviation sqrt(1/3) * pi"
    s = sqrt(1/3) * pi
    return np.exp(-t*t/(2*s*s)) / sqrt(2 * pi) / s

# %% [markdown]
# Let us plot both the derivative of the sigmoid function and the Gauss function with standard deviation $\large\frac{\pi}{\sqrt{3}}$.

# %%
n = 1000
X = np.linspace(-8.0, 8.0, num=n)
Y = sigmoidPrime(X)
G = gauss(X)
Z = np.zeros((n,1))
sns.set(style='whitegrid')
plt.figure(figsize=(15, 10))
plt.margins(0.02)
plt.plot(X, Y, color='b', label='S´(t)')
plt.plot(X, G, color='r', label='G(t)')
plt.axvline(x=0.0, c='k')
plt.axhline(y=0.0, c='k')
plt.xticks(np.arange(-8.0, 8.1, step=0.5))
plt.yticks(np.arange(0.0, 0.26, step=0.01))
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("The derivative of the sigmoid function.");

# %% [markdown]
# It is apparent that the derivative of the sigmoid function has a shape that is similar to the shape of a Gaussian distribution.
