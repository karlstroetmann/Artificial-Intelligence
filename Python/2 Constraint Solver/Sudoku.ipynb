# %%
from IPython.core.display import HTML
with open('../style.css') as f:
    css = f.read()
HTML(css)
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
# <link href="http://fonts.googleapis.com/css?family=Sacramento" rel="stylesheet" type="text/css">
#
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# .container { width: 100% }
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Philosopher', sans-serif;
#     font-weight: 400;
#     font-size: 2.2em;
#     line-height: 100%;
#     color: rgb(0, 80, 120);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Philosopher', serif;
#     font-weight: 400;
#     font-size: 1.9em;
#     line-height: 100%;
#     color: rgb(200,100,0);
#     margin-bottom: 0.1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Philosopher', serif;
#     margin-top:12px;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: rgb(94,127,192);
# }
#
# .text_cell_render h4 {
#     font-family: 'Philosopher', serif;
# }
#
# .text_cell_render h5 {
#     font-family: 'Alegreya Sans', sans-serif;
#     font-weight: 300;
#     font-size: 16pt;
#     color: grey;
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.1em;
#     display: block;
# }
#
# .text_cell_render h6 {
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 10pt;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .text_cell_render em {
#     font-family: 'Philosopher', sans-serif;
#     color:        blue;
#     background-color: rgb(255,220,180);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   100;
# }
#
# .text_cell_render b {
#     color:            rgb(255,195,195);
#     background-color: rgb(0,0,0);
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   650;
# }
#
# .text_cell_render u {
#     color:            blue;
#     font-size:    110%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   650;
# }
#
# .text_cell_render tt {
#     font-size:    120%;
#     margin-left:   2px;
#     margin-right:  2px;
#     font-weight:   150;
# }
#
# .Codemirror {
#     font-family: "PT Mono";
#     font-size: 100%;
# }
#
# #fancy {
#     font-family:      Georgia;
#     position:         relative;
#     float:            left;
#     border:           2px solid red;
#     width:            600px;
#     padding-left:     20px;
#     padding-right:    20px;
#     padding-top:      10px;
#     font-family:      'Sacramento', cursive;
#     font-size:        26px;
#     background-color: #F4EBF3;
#     border-radius:    15px;
# }
#
# </Style>

# %% [markdown]
# # Sudoku

# %% [markdown]
# The sudoku we want to solve is shown below:
#     <img src="sudoku.png">
# It can be represented as a list of lists.

# %%
def create_puzzle():
    return [ ["*",  3 ,  9 , "*", "*", "*", "*", "*",  7 ], 
             ["*", "*", "*",  7 , "*", "*",  4 ,  9 ,  2 ],
             ["*", "*", "*", "*",  6 ,  5 , "*",  8 ,  3 ],
             ["*", "*", "*",  6 , "*",  3 ,  2 ,  7 , "*"],
             ["*", "*", "*", "*",  4 , "*",  8 , "*", "*"],
             [ 5 ,  6 , "*", "*", "*", "*", "*", "*", "*"],
             ["*", "*",  5 ,  2 , "*",  9 , "*", "*",  1 ],
             ["*",  2 ,  1 , "*", "*", "*", "*",  4 , "*"],
             [ 7 , "*", "*", "*", "*", "*",  5 , "*", "*"]
           ]

# %% [markdown]
# The function `allDifferent` takes a list `L` as its argument.  This list contains both variables and numbers.
# It returns a set of formulas expressing that all variables from `L` take different values.

# %%
def allDifferent(Variables):
    return { f'{x} != {y}' for x in Variables 
                           for y in Variables
                           if  x < y
           }

# %%
def constraints_from_puzzle(Puzzle):
    return { f'V{row+1}{col+1} == {Puzzle[row][col]}' for row in range(9)
                                                      for col in range(9)
                                                      if  Puzzle[row][col] != '*'
           }

# %%
constraints_from_puzzle(create_puzzle())
# Out:
# {'V12 == 3',
#  'V13 == 9',
#  'V19 == 7',
#  'V24 == 7',
#  'V27 == 4',
#  'V28 == 9',
#  'V29 == 2',
#  'V35 == 6',
#  'V36 == 5',
#  'V38 == 8',
#  'V39 == 3',
#  'V44 == 6',
#  'V46 == 3',
#  'V47 == 2',
#  'V48 == 7',
#  'V55 == 4',
#  'V57 == 8',
#  'V61 == 5',
#  'V62 == 6',
#  'V73 == 5',
#  'V74 == 2',
#  'V76 == 9',
#  'V79 == 1',
#  'V82 == 2',
#  'V83 == 1',
#  'V88 == 4',
#  'V91 == 7',
#  'V97 == 5'}

# %% [markdown]
# The function `sudoku_csp` returns a CSP that encodes the given sudoku as a CSP.

# %%
def sudoku_csp():
    Puzzle = create_puzzle()
    L           = range(1, 9+1)
    Variables   = { f'V{row}{col}' for row in L
                                   for col in L
                  }
    Values      = set(L)
    Constraints = constraints_from_puzzle(Puzzle)
    # all entries in a row are unique
    for row in L:
        Constraints |= allDifferent({ f'V{row}{col}' for col in L })
    # all entries in a column are unique
    for col in L:
        Constraints |= allDifferent({ f'V{row}{col}' for row in L })
    # all entries in a square are unique    
    for r in range(3):
        for c in range(3):
            S = { f'V{r*3+row}{c*3+col}' for row in range(1, 3+1)
                                         for col in range(1, 3+1) 
                }
            Constraints |= allDifferent(S)
    return Variables, Values, Constraints

# %%
sudoku_csp()
# Out:
# ({'V11',
#   'V12',
#   'V13',
#   'V14',
#   'V15',
#   'V16',
#   'V17',
#   'V18',
#   'V19',
#   'V21',
#   'V22',
#   'V23',
#   'V24',
#   'V25',
#   'V26',
#   'V27',
#   'V28',
#   'V29',
#   'V31',
#   'V32',
#   'V33',
#   'V34',
#   'V35',
#   'V36',
#   'V37',
#   'V38',
#   'V39',
#   'V41',
#   'V42',
#   'V43',
#   'V44',
#   'V45',
#   'V46',
#   'V47',
#   'V48',
#   'V49',
#   'V51',
#   'V52',
#   'V53',
#   'V54',
#   'V55',
#   'V56',
#   'V57',
#   'V58',
#   'V59',
#   'V61',
#   'V62',
#   'V63',
#   'V64',
#   'V65',
#   'V66',
#   'V67',
#   'V68',
#   'V69',
#   'V71',
#   'V72',
#   'V73',
#   'V74',
#   'V75',
#   'V76',
#   'V77',
#   'V78',
#   'V79',
#   'V81',
#   'V82',
#   'V83',
#   'V84',
#   'V85',
#   'V86',
#   'V87',
#   'V88',
#   'V89',
#   'V91',
#   'V92',
#   'V93',
#   'V94',
#   'V95',
#   'V96',
#   'V97',
#   'V98',
#   'V99'},
#  {1, 2, 3, 4, 5, 6, 7, 8, 9},
#  {'V11 != V12',
#   'V11 != V13',
#   'V11 != V14',
#   'V11 != V15',
#   'V11 != V16',
#   'V11 != V17',
#   'V11 != V18',
#   'V11 != V19',
#   'V11 != V21',
#   'V11 != V22',
#   'V11 != V23',
#   'V11 != V31',
#   'V11 != V32',
#   'V11 != V33',
#   'V11 != V41',
#   'V11 != V51',
#   'V11 != V61',
#   'V11 != V71',
#   'V11 != V81',
#   'V11 != V91',
#   'V12 != V13',
#   'V12 != V14',
#   'V12 != V15',
#   'V12 != V16',
#   'V12 != V17',
#   'V12 != V18',
#   'V12 != V19',
#   'V12 != V21',
#   'V12 != V22',
#   'V12 != V23',
#   'V12 != V31',
#   'V12 != V32',
#   'V12 != V33',
#   'V12 != V42',
#   'V12 != V52',
#   'V12 != V62',
#   'V12 != V72',
#   'V12 != V82',
#   'V12 != V92',
#   'V12 == 3',
#   'V13 != V14',
#   'V13 != V15',
#   'V13 != V16',
#   'V13 != V17',
#   'V13 != V18',
#   'V13 != V19',
#   'V13 != V21',
#   'V13 != V22',
#   'V13 != V23',
#   'V13 != V31',
#   'V13 != V32',
#   'V13 != V33',
#   'V13 != V43',
#   'V13 != V53',
#   'V13 != V63',
#   'V13 != V73',
#   'V13 != V83',
#   'V13 != V93',
#   'V13 == 9',
#   'V14 != V15',
#   'V14 != V16',
#   'V14 != V17',
#   'V14 != V18',
#   'V14 != V19',
#   'V14 != V24',
#   'V14 != V25',
#   'V14 != V26',
#   'V14 != V34',
#   'V14 != V35',
#   'V14 != V36',
#   'V14 != V44',
#   'V14 != V54',
#   'V14 != V64',
#   'V14 != V74',
#   'V14 != V84',
#   'V14 != V94',
#   'V15 != V16',
#   'V15 != V17',
#   'V15 != V18',
#   'V15 != V19',
#   'V15 != V24',
#   'V15 != V25',
#   'V15 != V26',
#   'V15 != V34',
#   'V15 != V35',
#   'V15 != V36',
#   'V15 != V45',
#   'V15 != V55',
#   'V15 != V65',
#   'V15 != V75',
#   'V15 != V85',
#   'V15 != V95',
#   'V16 != V17',
#   'V16 != V18',
#   'V16 != V19',
#   'V16 != V24',
#   'V16 != V25',
#   'V16 != V26',
#   'V16 != V34',
#   'V16 != V35',
#   'V16 != V36',
#   'V16 != V46',
#   'V16 != V56',
#   'V16 != V66',
#   'V16 != V76',
#   'V16 != V86',
#   'V16 != V96',
#   'V17 != V18',
#   'V17 != V19',
#   'V17 != V27',
#   'V17 != V28',
#   'V17 != V29',
#   'V17 != V37',
#   'V17 != V38',
#   'V17 != V39',
#   'V17 != V47',
#   'V17 != V57',
#   'V17 != V67',
#   'V17 != V77',
#   'V17 != V87',
#   'V17 != V97',
#   'V18 != V19',
#   'V18 != V27',
#   'V18 != V28',
#   'V18 != V29',
#   'V18 != V37',
#   'V18 != V38',
#   'V18 != V39',
#   'V18 != V48',
#   'V18 != V58',
#   'V18 != V68',
#   'V18 != V78',
#   'V18 != V88',
#   'V18 != V98',
#   'V19 != V27',
#   'V19 != V28',
#   'V19 != V29',
#   'V19 != V37',
#   'V19 != V38',
#   'V19 != V39',
#   'V19 != V49',
#   'V19 != V59',
#   'V19 != V69',
#   'V19 != V79',
#   'V19 != V89',
#   'V19 != V99',
#   'V19 == 7',
#   'V21 != V22',
#   'V21 != V23',
#   'V21 != V24',
#   'V21 != V25',
#   'V21 != V26',
#   'V21 != V27',
#   'V21 != V28',
#   'V21 != V29',
#   'V21 != V31',
#   'V21 != V32',
#   'V21 != V33',
#   'V21 != V41',
#   'V21 != V51',
#   'V21 != V61',
#   'V21 != V71',
#   'V21 != V81',
#   'V21 != V91',
#   'V22 != V23',
#   'V22 != V24',
#   'V22 != V25',
#   'V22 != V26',
#   'V22 != V27',
#   'V22 != V28',
#   'V22 != V29',
#   'V22 != V31',
#   'V22 != V32',
#   'V22 != V33',
#   'V22 != V42',
#   'V22 != V52',
#   'V22 != V62',
#   'V22 != V72',
#   'V22 != V82',
#   'V22 != V92',
#   'V23 != V24',
#   'V23 != V25',
#   'V23 != V26',
#   'V23 != V27',
#   'V23 != V28',
#   'V23 != V29',
#   'V23 != V31',
#   'V23 != V32',
#   'V23 != V33',
#   'V23 != V43',
#   'V23 != V53',
#   'V23 != V63',
#   'V23 != V73',
#   'V23 != V83',
#   'V23 != V93',
#   'V24 != V25',
#   'V24 != V26',
#   'V24 != V27',
#   'V24 != V28',
#   'V24 != V29',
#   'V24 != V34',
#   'V24 != V35',
#   'V24 != V36',
#   'V24 != V44',
#   'V24 != V54',
#   'V24 != V64',
#   'V24 != V74',
#   'V24 != V84',
#   'V24 != V94',
#   'V24 == 7',
#   'V25 != V26',
#   'V25 != V27',
#   'V25 != V28',
#   'V25 != V29',
#   'V25 != V34',
#   'V25 != V35',
#   'V25 != V36',
#   'V25 != V45',
#   'V25 != V55',
#   'V25 != V65',
#   'V25 != V75',
#   'V25 != V85',
#   'V25 != V95',
#   'V26 != V27',
#   'V26 != V28',
#   'V26 != V29',
#   'V26 != V34',
#   'V26 != V35',
#   'V26 != V36',
#   'V26 != V46',
#   'V26 != V56',
#   'V26 != V66',
#   'V26 != V76',
#   'V26 != V86',
#   'V26 != V96',
#   'V27 != V28',
#   'V27 != V29',
#   'V27 != V37',
#   'V27 != V38',
#   'V27 != V39',
#   'V27 != V47',
#   'V27 != V57',
#   'V27 != V67',
#   'V27 != V77',
#   'V27 != V87',
#   'V27 != V97',
#   'V27 == 4',
#   'V28 != V29',
#   'V28 != V37',
#   'V28 != V38',
#   'V28 != V39',
#   'V28 != V48',
#   'V28 != V58',
#   'V28 != V68',
#   'V28 != V78',
#   'V28 != V88',
#   'V28 != V98',
#   'V28 == 9',
#   'V29 != V37',
#   'V29 != V38',
#   'V29 != V39',
#   'V29 != V49',
#   'V29 != V59',
#   'V29 != V69',
#   'V29 != V79',
#   'V29 != V89',
#   'V29 != V99',
#   'V29 == 2',
#   'V31 != V32',
#   'V31 != V33',
#   'V31 != V34',
#   'V31 != V35',
#   'V31 != V36',
#   'V31 != V37',
#   'V31 != V38',
#   'V31 != V39',
#   'V31 != V41',
#   'V31 != V51',
#   'V31 != V61',
#   'V31 != V71',
#   'V31 != V81',
#   'V31 != V91',
#   'V32 != V33',
#   'V32 != V34',
#   'V32 != V35',
#   'V32 != V36',
#   'V32 != V37',
#   'V32 != V38',
#   'V32 != V39',
#   'V32 != V42',
#   'V32 != V52',
#   'V32 != V62',
#   'V32 != V72',
#   'V32 != V82',
#   'V32 != V92',
#   'V33 != V34',
#   'V33 != V35',
#   'V33 != V36',
#   'V33 != V37',
#   'V33 != V38',
#   'V33 != V39',
#   'V33 != V43',
#   'V33 != V53',
#   'V33 != V63',
#   'V33 != V73',
#   'V33 != V83',
#   'V33 != V93',
#   'V34 != V35',
#   'V34 != V36',
#   'V34 != V37',
#   'V34 != V38',
#   'V34 != V39',
#   'V34 != V44',
#   'V34 != V54',
#   'V34 != V64',
#   'V34 != V74',
#   'V34 != V84',
#   'V34 != V94',
#   'V35 != V36',
#   'V35 != V37',
#   'V35 != V38',
#   'V35 != V39',
#   'V35 != V45',
#   'V35 != V55',
#   'V35 != V65',
#   'V35 != V75',
#   'V35 != V85',
#   'V35 != V95',
#   'V35 == 6',
#   'V36 != V37',
#   'V36 != V38',
#   'V36 != V39',
#   'V36 != V46',
#   'V36 != V56',
#   'V36 != V66',
#   'V36 != V76',
#   'V36 != V86',
#   'V36 != V96',
#   'V36 == 5',
#   'V37 != V38',
#   'V37 != V39',
#   'V37 != V47',
#   'V37 != V57',
#   'V37 != V67',
#   'V37 != V77',
#   'V37 != V87',
#   'V37 != V97',
#   'V38 != V39',
#   'V38 != V48',
#   'V38 != V58',
#   'V38 != V68',
#   'V38 != V78',
#   'V38 != V88',
#   'V38 != V98',
#   'V38 == 8',
#   'V39 != V49',
#   'V39 != V59',
#   'V39 != V69',
#   'V39 != V79',
#   'V39 != V89',
#   'V39 != V99',
#   'V39 == 3',
#   'V41 != V42',
#   'V41 != V43',
#   'V41 != V44',
#   'V41 != V45',
#   'V41 != V46',
#   'V41 != V47',
#   'V41 != V48',
#   'V41 != V49',
#   'V41 != V51',
#   'V41 != V52',
#   'V41 != V53',
#   'V41 != V61',
#   'V41 != V62',
#   'V41 != V63',
#   'V41 != V71',
#   'V41 != V81',
#   'V41 != V91',
#   'V42 != V43',
#   'V42 != V44',
#   'V42 != V45',
#   'V42 != V46',
#   'V42 != V47',
#   'V42 != V48',
#   'V42 != V49',
#   'V42 != V51',
#   'V42 != V52',
#   'V42 != V53',
#   'V42 != V61',
#   'V42 != V62',
#   'V42 != V63',
#   'V42 != V72',
#   'V42 != V82',
#   'V42 != V92',
#   'V43 != V44',
#   'V43 != V45',
#   'V43 != V46',
#   'V43 != V47',
#   'V43 != V48',
#   'V43 != V49',
#   'V43 != V51',
#   'V43 != V52',
#   'V43 != V53',
#   'V43 != V61',
#   'V43 != V62',
#   'V43 != V63',
#   'V43 != V73',
#   'V43 != V83',
#   'V43 != V93',
#   'V44 != V45',
#   'V44 != V46',
#   'V44 != V47',
#   'V44 != V48',
#   'V44 != V49',
#   'V44 != V54',
#   'V44 != V55',
#   'V44 != V56',
#   'V44 != V64',
#   'V44 != V65',
#   'V44 != V66',
#   'V44 != V74',
#   'V44 != V84',
#   'V44 != V94',
#   'V44 == 6',
#   'V45 != V46',
#   'V45 != V47',
#   'V45 != V48',
#   'V45 != V49',
#   'V45 != V54',
#   'V45 != V55',
#   'V45 != V56',
#   'V45 != V64',
#   'V45 != V65',
#   'V45 != V66',
#   'V45 != V75',
#   'V45 != V85',
#   'V45 != V95',
#   'V46 != V47',
#   'V46 != V48',
#   'V46 != V49',
#   'V46 != V54',
#   'V46 != V55',
#   'V46 != V56',
#   'V46 != V64',
#   'V46 != V65',
#   'V46 != V66',
#   'V46 != V76',
#   'V46 != V86',
#   'V46 != V96',
#   'V46 == 3',
#   'V47 != V48',
#   'V47 != V49',
#   'V47 != V57',
#   'V47 != V58',
#   'V47 != V59',
#   'V47 != V67',
#   'V47 != V68',
#   'V47 != V69',
#   'V47 != V77',
#   'V47 != V87',
#   'V47 != V97',
#   'V47 == 2',
#   'V48 != V49',
#   'V48 != V57',
#   'V48 != V58',
#   'V48 != V59',
#   'V48 != V67',
#   'V48 != V68',
#   'V48 != V69',
#   'V48 != V78',
#   'V48 != V88',
#   'V48 != V98',
#   'V48 == 7',
#   'V49 != V57',
#   'V49 != V58',
#   'V49 != V59',
#   'V49 != V67',
#   'V49 != V68',
#   'V49 != V69',
#   'V49 != V79',
#   'V49 != V89',
#   'V49 != V99',
#   'V51 != V52',
#   'V51 != V53',
#   'V51 != V54',
#   'V51 != V55',
#   'V51 != V56',
#   'V51 != V57',
#   'V51 != V58',
#   'V51 != V59',
#   'V51 != V61',
#   'V51 != V62',
#   'V51 != V63',
#   'V51 != V71',
#   'V51 != V81',
#   'V51 != V91',
#   'V52 != V53',
#   'V52 != V54',
#   'V52 != V55',
#   'V52 != V56',
#   'V52 != V57',
#   'V52 != V58',
#   'V52 != V59',
#   'V52 != V61',
#   'V52 != V62',
#   'V52 != V63',
#   'V52 != V72',
#   'V52 != V82',
#   'V52 != V92',
#   'V53 != V54',
#   'V53 != V55',
#   'V53 != V56',
#   'V53 != V57',
#   'V53 != V58',
#   'V53 != V59',
#   'V53 != V61',
#   'V53 != V62',
#   'V53 != V63',
#   'V53 != V73',
#   'V53 != V83',
#   'V53 != V93',
#   'V54 != V55',
#   'V54 != V56',
#   'V54 != V57',
#   'V54 != V58',
#   'V54 != V59',
#   'V54 != V64',
#   'V54 != V65',
#   'V54 != V66',
#   'V54 != V74',
#   'V54 != V84',
#   'V54 != V94',
#   'V55 != V56',
#   'V55 != V57',
#   'V55 != V58',
#   'V55 != V59',
#   'V55 != V64',
#   'V55 != V65',
#   'V55 != V66',
#   'V55 != V75',
#   'V55 != V85',
#   'V55 != V95',
#   'V55 == 4',
#   'V56 != V57',
#   'V56 != V58',
#   'V56 != V59',
#   'V56 != V64',
#   'V56 != V65',
#   'V56 != V66',
#   'V56 != V76',
#   'V56 != V86',
#   'V56 != V96',
#   'V57 != V58',
#   'V57 != V59',
#   'V57 != V67',
#   'V57 != V68',
#   'V57 != V69',
#   'V57 != V77',
#   'V57 != V87',
#   'V57 != V97',
#   'V57 == 8',
#   'V58 != V59',
#   'V58 != V67',
#   'V58 != V68',
#   'V58 != V69',
#   'V58 != V78',
#   'V58 != V88',
#   'V58 != V98',
#   'V59 != V67',
#   'V59 != V68',
#   'V59 != V69',
#   'V59 != V79',
#   'V59 != V89',
#   'V59 != V99',
#   'V61 != V62',
#   'V61 != V63',
#   'V61 != V64',
#   'V61 != V65',
#   'V61 != V66',
#   'V61 != V67',
#   'V61 != V68',
#   'V61 != V69',
#   'V61 != V71',
#   'V61 != V81',
#   'V61 != V91',
#   'V61 == 5',
#   'V62 != V63',
#   'V62 != V64',
#   'V62 != V65',
#   'V62 != V66',
#   'V62 != V67',
#   'V62 != V68',
#   'V62 != V69',
#   'V62 != V72',
#   'V62 != V82',
#   'V62 != V92',
#   'V62 == 6',
#   'V63 != V64',
#   'V63 != V65',
#   'V63 != V66',
#   'V63 != V67',
#   'V63 != V68',
#   'V63 != V69',
#   'V63 != V73',
#   'V63 != V83',
#   'V63 != V93',
#   'V64 != V65',
#   'V64 != V66',
#   'V64 != V67',
#   'V64 != V68',
#   'V64 != V69',
#   'V64 != V74',
#   'V64 != V84',
#   'V64 != V94',
#   'V65 != V66',
#   'V65 != V67',
#   'V65 != V68',
#   'V65 != V69',
#   'V65 != V75',
#   'V65 != V85',
#   'V65 != V95',
#   'V66 != V67',
#   'V66 != V68',
#   'V66 != V69',
#   'V66 != V76',
#   'V66 != V86',
#   'V66 != V96',
#   'V67 != V68',
#   'V67 != V69',
#   'V67 != V77',
#   'V67 != V87',
#   'V67 != V97',
#   'V68 != V69',
#   'V68 != V78',
#   'V68 != V88',
#   'V68 != V98',
#   'V69 != V79',
#   'V69 != V89',
#   'V69 != V99',
#   'V71 != V72',
#   'V71 != V73',
#   'V71 != V74',
#   'V71 != V75',
#   'V71 != V76',
#   'V71 != V77',
#   'V71 != V78',
#   'V71 != V79',
#   'V71 != V81',
#   'V71 != V82',
#   'V71 != V83',
#   'V71 != V91',
#   'V71 != V92',
#   'V71 != V93',
#   'V72 != V73',
#   'V72 != V74',
#   'V72 != V75',
#   'V72 != V76',
#   'V72 != V77',
#   'V72 != V78',
#   'V72 != V79',
#   'V72 != V81',
#   'V72 != V82',
#   'V72 != V83',
#   'V72 != V91',
#   'V72 != V92',
#   'V72 != V93',
#   'V73 != V74',
#   'V73 != V75',
#   'V73 != V76',
#   'V73 != V77',
#   'V73 != V78',
#   'V73 != V79',
#   'V73 != V81',
#   'V73 != V82',
#   'V73 != V83',
#   'V73 != V91',
#   'V73 != V92',
#   'V73 != V93',
#   'V73 == 5',
#   'V74 != V75',
#   'V74 != V76',
#   'V74 != V77',
#   'V74 != V78',
#   'V74 != V79',
#   'V74 != V84',
#   'V74 != V85',
#   'V74 != V86',
#   'V74 != V94',
#   'V74 != V95',
#   'V74 != V96',
#   'V74 == 2',
#   'V75 != V76',
#   'V75 != V77',
#   'V75 != V78',
#   'V75 != V79',
#   'V75 != V84',
#   'V75 != V85',
#   'V75 != V86',
#   'V75 != V94',
#   'V75 != V95',
#   'V75 != V96',
#   'V76 != V77',
#   'V76 != V78',
#   'V76 != V79',
#   'V76 != V84',
#   'V76 != V85',
#   'V76 != V86',
#   'V76 != V94',
#   'V76 != V95',
#   'V76 != V96',
#   'V76 == 9',
#   'V77 != V78',
#   'V77 != V79',
#   'V77 != V87',
#   'V77 != V88',
#   'V77 != V89',
#   'V77 != V97',
#   'V77 != V98',
#   'V77 != V99',
#   'V78 != V79',
#   'V78 != V87',
#   'V78 != V88',
#   'V78 != V89',
#   'V78 != V97',
#   'V78 != V98',
#   'V78 != V99',
#   'V79 != V87',
#   'V79 != V88',
#   'V79 != V89',
#   'V79 != V97',
#   'V79 != V98',
#   'V79 != V99',
#   'V79 == 1',
#   'V81 != V82',
#   'V81 != V83',
#   'V81 != V84',
#   'V81 != V85',
#   'V81 != V86',
#   'V81 != V87',
#   'V81 != V88',
#   'V81 != V89',
#   'V81 != V91',
#   'V81 != V92',
#   'V81 != V93',
#   'V82 != V83',
#   'V82 != V84',
#   'V82 != V85',
#   'V82 != V86',
#   'V82 != V87',
#   'V82 != V88',
#   'V82 != V89',
#   'V82 != V91',
#   'V82 != V92',
#   'V82 != V93',
#   'V82 == 2',
#   'V83 != V84',
#   'V83 != V85',
#   'V83 != V86',
#   'V83 != V87',
#   'V83 != V88',
#   'V83 != V89',
#   'V83 != V91',
#   'V83 != V92',
#   'V83 != V93',
#   'V83 == 1',
#   'V84 != V85',
#   'V84 != V86',
#   'V84 != V87',
#   'V84 != V88',
#   'V84 != V89',
#   'V84 != V94',
#   'V84 != V95',
#   'V84 != V96',
#   'V85 != V86',
#   'V85 != V87',
#   'V85 != V88',
#   'V85 != V89',
#   'V85 != V94',
#   'V85 != V95',
#   'V85 != V96',
#   'V86 != V87',
#   'V86 != V88',
#   'V86 != V89',
#   'V86 != V94',
#   'V86 != V95',
#   'V86 != V96',
#   'V87 != V88',
#   'V87 != V89',
#   'V87 != V97',
#   'V87 != V98',
#   'V87 != V99',
#   'V88 != V89',
#   'V88 != V97',
#   'V88 != V98',
#   'V88 != V99',
#   'V88 == 4',
#   'V89 != V97',
#   'V89 != V98',
#   'V89 != V99',
#   'V91 != V92',
#   'V91 != V93',
#   'V91 != V94',
#   'V91 != V95',
#   'V91 != V96',
#   'V91 != V97',
#   'V91 != V98',
#   'V91 != V99',
#   'V91 == 7',
#   'V92 != V93',
#   'V92 != V94',
#   'V92 != V95',
#   'V92 != V96',
#   'V92 != V97',
#   'V92 != V98',
#   'V92 != V99',
#   'V93 != V94',
#   'V93 != V95',
#   'V93 != V96',
#   'V93 != V97',
#   'V93 != V98',
#   'V93 != V99',
#   'V94 != V95',
#   'V94 != V96',
#   'V94 != V97',
#   'V94 != V98',
#   'V94 != V99',
#   'V95 != V96',
#   'V95 != V97',
#   'V95 != V98',
#   'V95 != V99',
#   'V96 != V97',
#   'V96 != V98',
#   'V96 != V99',
#   'V97 != V98',
#   'V97 != V99',
#   'V97 == 5',
#   'V98 != V99'})

# %% [markdown]
# Given a sudoku `Puzzle` and a `Solution` for this puzzle, the function `find_alternative` computes a CSP
# that is solvable iff the puzzle has a second solution that is different from `Solution`.

# %%
def find_alternative(csp, Solution):
    Variables, Values, Constraints = csp
    formula = ' or '.join({ f'{var} != {Solution[var]}' for var in Variables })
    return Variables, Values, Constraints | { formula }

# %% [markdown]
# ## Graphical Representation

# %% [markdown]
# The following line needs to be executed once to install the package `problem_visuals`.

# %%
# !pip install git+https://github.com/reclinarka/problem_visuals
# Out:
# Collecting git+https://github.com/reclinarka/problem_visuals
#   Cloning https://github.com/reclinarka/problem_visuals to /private/var/folders/j0/9pg05lc57pd41f8b7d_b7sv40000gq/T/pip-req-build-1_p8yf6w
#   Running command git clone --filter=blob:none --quiet https://github.com/reclinarka/problem_visuals /private/var/folders/j0/9pg05lc57pd41f8b7d_b7sv40000gq/T/pip-req-build-1_p8yf6w
#   Resolved https://github.com/reclinarka/problem_visuals to commit 686d00067dd5f1eee5f227d2967368eba74f11b3
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: problem-visuals
#   Building wheel for problem-visuals (setup.py) ... done
#   Created wheel for problem-visuals: filename=problem_visuals-0.6.1-py3-none-any.whl size=15800 sha256=55fcafedf48b46e554f2f21466c5b4e72a7fd93d94ec103092f39084ed77f7bc
#   Stored in directory: /private/var/folders/j0/9pg05lc57pd41f8b7d_b7sv40000gq/T/pip-ephem-wheel-cache-o47g6ukm/wheels/94/73/6d/92b7b9904c480ab6a5e8d7acd2354ba7bd62644913a2616f10
# Successfully built problem-visuals
# Installing collected packages: problem-visuals
# Successfully installed problem-visuals-0.6.1

# %%
from problem_visuals.games.sudoku.grid import Grid

# %% [markdown]
# The function `show_solution` prints the solution.

# %%
def show_solution(Solution, width='50%'):
    Sudoku = create_puzzle()
    Assignment = Solution.copy()
    for row in range(9):
        for col in range(9):
            if Sudoku[row][col] != '*':
                del Assignment[f'V{row+1}{col+1}']
    return Grid(state=Sudoku, assigned=Assignment, html_width=width)
